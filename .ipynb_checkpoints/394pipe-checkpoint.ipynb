# %% [markdown]
# ### IEMS 394
#
# #### Data Pipeline
# Objective: Load and clean data, save as pickle.

# %%
# %%time
import matplotlib.pyplot as plt
from shapely.geometry import shape, Point, Polygon
import pandas as pd
from tqdm import tqdm
import os, geojson, multiprocessing, datetime, time
import concurrent.futures
# %matplotlib tk

os.chdir('/Users/saifbhatti/Desktop/Northwestern/sy1920/s20/iems394/client-data/cleaned_data')

with open('us_counties_2010.json', encoding = "ISO-8859-1") as f:
    gj = geojson.load(f)
    
    
selected_states = ['TX','CA','MN']
# Out:
# CPU times: user 2.1 s, sys: 92.6 ms, total: 2.2 s
# Wall time: 2.23 s

# %% [markdown]
# ### Vision (end goals)
#
# - Data Cleaning (python file)
#     - read in appropriate csv files that have been cleaned
#     - convert to dataframe
#     - pickle
# - AMPL szn (python file)
#     - unpickle
#     - AMPLpy code that uses the dataframes as decision parameters
# - Visualisation (ipynb)
#     - either

# %% [markdown]
# ### Files
#
# Vehicle Data:
# - EV_Ranges.csv
# - vehicle_ages.csv
# - vehicles_available.csv
# - trip_purpose_miles.csv
# - HI_vehicles.csv
# - HEV_model-sales.csv
# - PEV_model-sales.csv
# - Distance.csv

# %% [markdown]
# #### Import and Clean Vehicle Data

# %%
df = pd.read_csv('HEV_model-sales.csv',skiprows=1,thousands=',')
df.drop('Total',axis=1,inplace=True)
df.drop(df.index[df.shape[0]-1],inplace=True)
df.set_index(df['Vehicle'],inplace=True)
df.drop('Vehicle',axis=1,inplace=True)
df = df.applymap(lambda x: x.replace('-','0'))
df = df.applymap(lambda x: x.replace(",", ""))
# df = df.applymap(lambda x: x=int(x))
cols=[i for i in df.columns if i not in ['Vehicle']]
for col in cols:
    df[col]=pd.to_numeric(df[col])
hybrid_df = df

# %%
#Total sum per column: 
hybrid_df['total']= hybrid_df.sum(axis=1)
hybrid_df['total'].plot(kind='bar',x='name',y='sales volume')

# %%
df = pd.read_csv('PEV_model-sales.csv',skiprows=1,thousands=',')
df.drop('Total',axis=1,inplace=True)
df.drop(df.index[df.shape[0]-1],inplace=True)
df.set_index(df['Vehicle'],inplace=True)
df.drop('Vehicle',axis=1,inplace=True)
# df.replace(to_replace='-',value=';')
df = df.applymap(lambda x: x.replace('-','0'))
df = df.applymap(lambda x: x.replace(",", ""))
cols=[i for i in df.columns if i not in ['Type']]
for col in cols:
    df[col]=pd.to_numeric(df[col])
electric_df = df

# %%
EV_ranges_df =  pd.read_csv('EV_ranges.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('electric_fuel_stations.csv')
electric_fuel_df = df
df.head()
# Out:
#    Unnamed: 0 Fuel Type Code  \
# 0           0           ELEC
# 1           1           ELEC
# 2           2           ELEC
# 3           3           ELEC
# 4           4           ELEC
#
#                                         Station Name         Street Address  \
# 0        City of Sacramento - Capitol Parking Garage              1015 L St
# 1                           LADWP - Truesdale Center     11797 Truesdale St
# 2  Southern California Edison - Rosemead Office B...  2244 Walnut Grove Ave
# 3                      Los Angeles Convention Center     1201 S Figueroa St
# 4                      LADWP - John Ferraro Building          111 N Hope St
#
#           City State    ZIP Status Code Groups With Access Code   Latitude  \
# 0   Sacramento    CA  95814           E                  Public  38.578380
# 1   Sun Valley    CA  91352           E                 Private  34.248319
# 2     Rosemead    CA  91770           E                 Private  34.050745
# 3  Los Angeles    CA  90015           E                  Public  34.040570
# 4  Los Angeles    CA  90012           E                 Private  34.058476
#
#    ...    ID Owner Type Code   Open Date EV Connector Types Country  \
# 0  ...  1498              LG   8/20/2018            NEMA520      US
# 1  ...  1517              LG  10/15/1999              J1772      US
# 2  ...  1520               T  08/01/2011      J1772 NEMA520      US
# 3  ...  1523               P   8/30/1995              J1772      US
# 4  ...  1525              LG  10/15/1999              J1772      US
#
#   Access Code   Facility Type EV Pricing EV On-Site Renewable Source  \
# 0      public      PAY_GARAGE        NaN                         NaN
# 1     private         UTILITY        NaN                         NaN
# 2     private         UTILITY        NaN                         NaN
# 3      public  PARKING_GARAGE        NaN                         NaN
# 4     private         UTILITY        NaN                         NaN
#
#         County
# 0   Sacramento
# 1  Los Angeles
# 2  Los Angeles
# 3  Los Angeles
# 4  Los Angeles
#
# [5 rows x 22 columns]

# %%
# df['point'] = df['Longitude'] + df['Latitude']
df['Points'] = list(zip(df['Longitude'], df['Latitude']))
# df.tail(20)
df.head()
# Out:
#    Unnamed: 0 Fuel Type Code  \
# 0           0           ELEC
# 1           1           ELEC
# 2           2           ELEC
# 3           3           ELEC
# 4           4           ELEC
#
#                                         Station Name         Street Address  \
# 0        City of Sacramento - Capitol Parking Garage              1015 L St
# 1                           LADWP - Truesdale Center     11797 Truesdale St
# 2  Southern California Edison - Rosemead Office B...  2244 Walnut Grove Ave
# 3                      Los Angeles Convention Center     1201 S Figueroa St
# 4                      LADWP - John Ferraro Building          111 N Hope St
#
#           City State    ZIP Status Code Groups With Access Code   Latitude  \
# 0   Sacramento    CA  95814           E                  Public  38.578380
# 1   Sun Valley    CA  91352           E                 Private  34.248319
# 2     Rosemead    CA  91770           E                 Private  34.050745
# 3  Los Angeles    CA  90015           E                  Public  34.040570
# 4  Los Angeles    CA  90012           E                 Private  34.058476
#
#    ...  Owner Type Code   Open Date  EV Connector Types Country Access Code  \
# 0  ...               LG   8/20/2018             NEMA520      US      public
# 1  ...               LG  10/15/1999               J1772      US     private
# 2  ...                T  08/01/2011       J1772 NEMA520      US     private
# 3  ...                P   8/30/1995               J1772      US      public
# 4  ...               LG  10/15/1999               J1772      US     private
#
#     Facility Type EV Pricing EV On-Site Renewable Source       County  \
# 0      PAY_GARAGE        NaN                         NaN   Sacramento
# 1         UTILITY        NaN                         NaN  Los Angeles
# 2         UTILITY        NaN                         NaN  Los Angeles
# 3  PARKING_GARAGE        NaN                         NaN  Los Angeles
# 4         UTILITY        NaN                         NaN  Los Angeles
#
#                            Points
# 0  (-121.4926, 38.57838020000001)
# 1     (-118.3879714, 34.24831915)
# 2        (-118.081014, 34.050745)
# 3         (-118.268762, 34.04057)
# 4         (-118.24819, 34.058476)
#
# [5 rows x 23 columns]

# %%
def geo_map(x):
    '''
    geo_map takes pandas Series object constructed in the format (longitude, latitude).
    Taking this as the point, a geo.json file is imported containing all US counties from the 2010 census as polygons.
    It computes whether the point is within a polygon, and returns a list of all matches. 
    If a point is not matched, it returns None.
    '''
    point = Point(x)
    for i in range(len(gj['features'])):
        polygon = shape(gj['features'][i]['geometry'])
        if polygon.contains(point):
            return gj['features'][i]['properties']['NAME']

# %%
def geo_two(x):
    '''
    geo_map takes pandas Series object constructed in the format (longitude, latitude).
    Taking this as the point, a geo.json file is imported containing all US counties from the 2010 census as polygons.
    It computes whether the point is within a polygon, and returns a list of all matches. 
    If a point is not matched, it returns None.
    '''
    counties = []
    for i in tqdm(x):
        point = Point(x)
        for i in range(len(gj['features'])):
            polygon = shape(gj['features'][i]['geometry'])
            if polygon.contains(point):
                counties.append(gj['features'][i]['properties']['NAME'])

# %%
counties = []
points_list = list(df['Points'])
# for i in tqdm(points_list):
#     counties.append(geo_map(i))

# %%
# electric_fuel_df['County'] = counties

# %%
# electric_fuel_df.to_csv('electric_fuel_stations.csv')

# %%
# electric_fuel_df

# %%
electric_df.to_pickle("./dummy.pkl")

# %% [markdown]
# ### Convert data from zipcode to county.

# %%
tx_ev_vehicle_registered = pd.read_csv('vehicle_reg/tx_ev_registrations_public.csv')
print(len(tx_ev_vehicle_registered['ZIP Code'].unique()))
print(len(tx_ev_vehicle_registered))
tx_ev_vehicle_registered.head()
# Out:
# 1325
# 74143
#    ZIP Code  DMV ID   Vehicle Name Registration Valid Date
# 0      3106       1  Tesla Model S              03/06/2019
# 1      3106       1  Tesla Model S              03/06/2019
# 2      3106       1  Tesla Model S              03/06/2019
# 3      3106       1  Tesla Model S              03/06/2019
# 4      3106       1  Tesla Model S              03/06/2019

# %%
mn_ev_vehicle_registered = pd.read_csv('vehicle_reg/mn_ev_registrations_public.csv')
mn_ev_vehicle_registered.drop(['VIN Prefix','VIN Model Year'],inplace=True,axis=1)
print(len(mn_ev_vehicle_registered['ZIP Code'].unique()))
print(len(mn_ev_vehicle_registered))
mn_ev_vehicle_registered.head()
# Out:
# 600
# 29248
#    DMV ID  ZIP Code Registration Expiration Date Registration Valid Date
# 0       6   55347.0                   01/12/2020              30/01/2020
# 1       6   55432.0                   01/12/2020              30/01/2020
# 2       6   55330.0                   01/07/2020              30/01/2020
# 3       6   56377.0                   01/04/2020              30/01/2020
# 4       6   55109.0                   01/12/2020              30/01/2020

# %%
result = pd.concat([mn_ev_vehicle_registered, tx_ev_vehicle_registered], axis=0)
print(len(result['ZIP Code'].unique()))
print(result.shape)
result.head()
# Out:
# 1906
# (103391, 5)
#    DMV ID  ZIP Code Registration Expiration Date Registration Valid Date  \
# 0       6   55347.0                   01/12/2020              30/01/2020
# 1       6   55432.0                   01/12/2020              30/01/2020
# 2       6   55330.0                   01/07/2020              30/01/2020
# 3       6   56377.0                   01/04/2020              30/01/2020
# 4       6   55109.0                   01/12/2020              30/01/2020
#
#   Vehicle Name
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
us_zips = pd.read_csv('uszips.csv')
print(us_zips.shape)
us_zips.head()
# Out:
# (33099, 18)
#    zip       lat       lng       city state_id   state_name  zcta  \
# 0  601  18.18004 -66.75218   Adjuntas       PR  Puerto Rico  True
# 1  602  18.36073 -67.17517     Aguada       PR  Puerto Rico  True
# 2  603  18.45439 -67.12202  Aguadilla       PR  Puerto Rico  True
# 3  606  18.16724 -66.93828    Maricao       PR  Puerto Rico  True
# 4  610  18.29032 -67.12243     Anasco       PR  Puerto Rico  True
#
#    parent_zcta  population  density  county_fips county_name  \
# 0          NaN       17242    111.4        72001    Adjuntas
# 1          NaN       38442    523.5        72003      Aguada
# 2          NaN       48814    667.9        72005   Aguadilla
# 3          NaN        6437     60.4        72093     Maricao
# 4          NaN       27073    312.0        72011      Añasco
#
#                               county_weights             county_names_all  \
# 0               {'72001':99.43,'72141':0.57}              Adjuntas|Utuado
# 1                              {'72003':100}                       Aguada
# 2                              {'72005':100}                    Aguadilla
# 3  {'72093':94.88,'72121':1.35,'72153':3.78}  Maricao|Yauco|Sabana Grande
# 4               {'72003':0.55,'72011':99.45}                Añasco|Aguada
#
#      county_fips_all  imprecise  military             timezone
# 0        72001|72141      False     False  America/Puerto_Rico
# 1              72003      False     False  America/Puerto_Rico
# 2              72005      False     False  America/Puerto_Rico
# 3  72093|72153|72121      False     False  America/Puerto_Rico
# 4        72011|72003      False     False  America/Puerto_Rico

# %%
# len(us_zips[(us_zips['zip'] > 70000) & (us_zips['zip'] < 90000)])

# %%
us_zips.columns
# Out:
# Index(['zip', 'lat', 'lng', 'city', 'state_id', 'state_name', 'zcta',
#        'parent_zcta', 'population', 'density', 'county_fips', 'county_name',
#        'county_weights', 'county_names_all', 'county_fips_all', 'imprecise',
#        'military', 'timezone'],
#       dtype='object')

# %%
new = pd.merge(result, us_zips, how='inner', left_on='ZIP Code', right_on='zip')

# %%
new['state_id'].unique()
# Out:
# array(['MN', 'CA', 'OH', 'MI', 'WI', 'IL', 'OR', 'MO', 'TX', 'NJ', 'AZ',
#        'CT', 'NE', 'FL', 'ID', 'CO', 'MD', 'NY', 'VA', 'IA', 'WY', 'MA',
#        'GA', 'WA', 'NH', 'PA', 'DC', 'NC', 'IN', 'KS', 'LA', 'OK', 'UT',
#        'NM', 'NV', 'KY', 'SC', 'AR', 'AK'], dtype=object)

# %%
len(new[(new['state_id'] == 'TX') | (new['state_id'] == 'MN')])
# Out:
# 97888

# %%
new.shape[0]
# Out:
# 101278

# %%
new = new[(new['state_id'] == 'TX') | (new['state_id'] == 'MN')]
new['state_id'].unique()
# Out:
# array(['MN', 'TX'], dtype=object)

# %%
new.columns
# Out:
# Index(['DMV ID', 'ZIP Code', 'Registration Expiration Date',
#        'Registration Valid Date', 'Vehicle Name', 'zip', 'lat', 'lng', 'city',
#        'state_id', 'state_name', 'zcta', 'parent_zcta', 'population',
#        'density', 'county_fips', 'county_name', 'county_weights',
#        'county_names_all', 'county_fips_all', 'imprecise', 'military',
#        'timezone'],
#       dtype='object')

# %%
new.groupby('state_id').count()
# Out:
#           DMV ID  ZIP Code  Registration Expiration Date  \
# state_id
# MN         29051     29051                         29045
# TX         68837     68837                             4
#
#           Registration Valid Date  Vehicle Name    zip    lat    lng   city  \
# state_id
# MN                          29048             6  29051  29051  29051  29051
# TX                          68837         68833  68837  68837  68837  68837
#
#           state_name  ...  population  density  county_fips  county_name  \
# state_id              ...
# MN             29051  ...       29051    29051        29051        29051
# TX             68837  ...       68837    68837        68837        68837
#
#           county_weights  county_names_all  county_fips_all  imprecise  \
# state_id
# MN                 29051             29051            29051      29051
# TX                 68837             68837            68837      68837
#
#           military  timezone
# state_id
# MN           29051     29051
# TX           68837     68837
#
# [2 rows x 22 columns]

# %%
new.to_csv('ev_registration_county.csv')

# %% [markdown]
# Within the `IRS Individual Tax Income` dataset, the following columns are extracted:
# - `STATE`: the relevant state the form was filed in.
# - `zipcode`: the relevant zipcode the form was filed in.
# - `NI`: Number of Returns.
# - `A02650`: Total Income Amount.
#
# Run `!curl https://www.irs.gov/pub/irs-soi/17zpallagi.csv -o irs.csv` to download.

# %%
irs = pd.read_csv('irs.csv') #read in the csv
irs = irs[['STATE','zipcode','A02650','N1']] #only keep a few columns (detailed above)
irs = irs.rename(columns={'A02650': 'total_income_amt', 'N1': 'return_count'})
irs.columns
# Out:
# Index(['STATE', 'zipcode', 'total_income_amt', 'return_count'], dtype='object')

# %%
irs['avg_income_amt'] = irs['total_income_amt'] / irs['return_count']

# %%
ranked_irs = irs.groupby('STATE').sum()
ranked_irs.sort_values(by='avg_income_amt', ascending=False)
# Out:
#          zipcode  total_income_amt  return_count  avg_income_amt
# STATE
# TX     751356162      1.834322e+09    24686880.0    1.090974e+06
# CA     828823507      3.131749e+09    35656240.0    1.078311e+06
# NY     117768024      1.726421e+09    19164470.0    9.463213e+05
# PA     141540136      8.694608e+08    12340460.0    7.837033e+05
# FL     183958530      1.497832e+09    19986410.0    7.564661e+05
# IL     454572582      9.359711e+08    12123320.0    6.642846e+05
# OH     266318932      6.956533e+08    11135420.0    5.858427e+05
# MI     261661764      6.124981e+08     9410350.0    5.438410e+05
# VA     111519642      6.317969e+08     7838560.0    4.483820e+05
# MN     265321122      4.220840e+08     5484850.0    4.426392e+05
# NC     122334024      5.851246e+08     9042620.0    4.367519e+05
# WI     231497946      3.776460e+08     5663430.0    4.312728e+05
# GA     125114100      6.140955e+08     8963430.0    4.147116e+05
# MO     344138819      3.521611e+08     5545270.0    4.105284e+05
# NJ      26479596      8.043301e+08     8778680.0    3.987921e+05
# IA     254208840      1.899992e+08     2876560.0    3.839285e+05
# IN     189985968      3.785539e+08     6203940.0    3.826423e+05
# MA       6010392      6.687087e+08     6843750.0    3.593246e+05
# TN     133873746      3.771473e+08     5995750.0    3.441772e+05
# WA     292856946      6.012923e+08     7049000.0    3.247255e+05
# AL     124417722      2.420705e+08     4068620.0    3.102764e+05
# OK     242378286      2.003173e+08     3207480.0    2.820493e+05
# KY     162387738      2.201010e+08     3792470.0    2.807876e+05
# KS     238500402      1.760802e+08     2628010.0    2.701260e+05
# LA     190870578      2.371221e+08     3884940.0    2.659649e+05
# MD      52011210      4.803380e+08     5911960.0    2.629317e+05
# CO     190495950      4.334059e+08     5352700.0    2.505399e+05
# NE     200340816      1.191341e+08     1784090.0    2.234296e+05
# SC      66389244      2.713253e+08     4425480.0    2.224102e+05
# AR     212556162      1.503391e+08     2428630.0    2.170726e+05
# OR     206212919      2.701507e+08     3819830.0    2.078407e+05
# CT      10691202      3.572929e+08     3492130.0    2.007100e+05
# WV      78907902      8.119133e+07     1515700.0    1.963688e+05
# MS      87010254      1.253096e+08     2437420.0    1.882390e+05
# AZ     150962742      4.024945e+08     5955380.0    1.865101e+05
# ME      10526490      7.932729e+07     1302180.0    1.828249e+05
# NH       5390190      1.109731e+08     1399170.0    1.558945e+05
# SD      99732804      5.413972e+07      823050.0    1.292490e+05
# ND      98720606      5.133119e+07      714620.0    1.219133e+05
# VT       8333472      4.133144e+07      645480.0    1.194823e+05
# UT      95193552      1.852662e+08     2619890.0    1.157039e+05
# ID     107864490      9.366322e+07     1500670.0    1.106028e+05
# MT      79774457      6.106907e+07      991870.0    1.052391e+05
# NV      68087112      1.963892e+08     2790940.0    9.918469e+04
# NM     109209854      9.993408e+07     1813710.0    9.481134e+04
# WY      53644644      4.170680e+07      532360.0    6.661186e+04
# RI       1786422      7.365220e+07     1062900.0    4.937502e+04
# HI      34273680      9.315946e+07     1362180.0    4.421151e+04
# DE       7160850      6.390416e+07      918910.0    3.995043e+04
# AK      32285712      4.873100e+07      690610.0    3.296206e+04
# DC       3241866      7.088072e+07      688560.0    1.993432e+04

# %%
irs = irs[irs['STATE'].isin(selected_states)] #keep only relevant states
irs.groupby('STATE').sum()
# Out:
#          zipcode  total_income_amt  return_count  avg_income_amt
# STATE
# CA     828823507      3.131749e+09    35656240.0    1.078311e+06
# MN     265321122      4.220840e+08     5484850.0    4.426392e+05
# TX     751356162      1.834322e+09    24686880.0    1.090974e+06

# %%
e85 = pd.read_csv('e85_fuel_stations.csv')

# %%
e85['Points'] = list(zip(e85['Longitude'], e85['Latitude']))
e85
# Out:
#      Fuel Type Code                   Station Name             City State  \
# 0               E85     Sioux Valley Co-op - Cenex        Watertown    SD
# 1               E85                  F&M Co-op Oil          Madison    SD
# 2               E85                  Kum & Go #113             Ames    IA
# 3               E85  Texaco - Highway 34 Truckstop  West Burlington    IA
# 4               E85  Conoco - Convenient Food Mart   Jefferson City    MO
# ...             ...                            ...              ...   ...
# 3556            E85   76 - Foothill Petroleum Inc.     La Crescenta    CA
# 3557            E85        Conoco - 130 Truck Stop      Cinnaminson    NJ
# 3558            E85                             BP        Fort Mill    SC
# 3559            E85                       Rutter's           Inwood    WV
# 3560            E85                       Rutter's     Walkersville    MD
#
#         ZIP   Latitude   Longitude      ID  E85 Blender Pump  \
# 0     57201  44.904113  -97.130798    1447              True
# 1     57042  44.007690  -97.146785    1451              True
# 2     50010  42.034894  -93.575925    1470              True
# 3     52655  40.825493  -91.208355    1479             False
# 4     65109  38.588189  -92.255887    1480             False
# ...     ...        ...         ...     ...               ...
# 3556  91214  34.232154 -118.253509  156016             False
# 3557   8077  40.006900  -74.975100  156023             False
# 3558  29708  35.030458  -80.966548  156024             False
# 3559  25428  39.404224  -78.016428  156025             False
# 3560  21793  39.487190  -77.340503  156026             False
#
#                                 Points
# 0              (-97.130798, 44.904113)
# 1     (-97.146785, 44.007690000000004)
# 2              (-93.575925, 42.034894)
# 3      (-91.20835500000001, 40.825493)
# 4              (-92.255887, 38.588189)
# ...                                ...
# 3556  (-118.25350900000001, 34.232154)
# 3557               (-74.9751, 40.0069)
# 3558           (-80.966548, 35.030458)
# 3559       (-78.01642778, 39.40422416)
# 3560  (-77.340503, 39.487190000000005)
#
# [3561 rows x 10 columns]

# %%
counties = []
points_list = list(e85['Points'])
for i in tqdm(points_list): counties.append(geo_map(i))
# Out:
#  11%|█         | 376/3561 [00:28<03:44, 14.21it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-822ef5527584> in <module>
#       2 points_list = list(e85['Points'])
#       3 for i in tqdm(points_list):
# ----> 4     counties.append(geo_map(i))
#
# <ipython-input-8-37b299b0408a> in geo_map(x)
#       8     point = Point(x)
#       9     for i in range(len(gj['features'])):
# ---> 10         polygon = shape(gj['features'][i]['geometry'])
#      11         if polygon.contains(point):
#      12             return gj['features'][i]['properties']['NAME']
#
# ~/anaconda3/lib/python3.6/site-packages/shapely/geometry/geo.py in shape(context)
#      33         return LineString(ob["coordinates"])
#      34     elif geom_type == "polygon":
# ---> 35         return Polygon(ob["coordinates"][0], ob["coordinates"][1:])
#      36     elif geom_type == "multipoint":
#      37         return MultiPoint(ob["coordinates"])
#
# ~/anaconda3/lib/python3.6/site-packages/shapely/geometry/polygon.py in __init__(self, shell, holes)
#     229
#     230         if shell is not None:
# --> 231             ret = geos_polygon_from_py(shell, holes)
#     232             if ret is not None:
#     233                 self._geom, self._ndim = ret
#
# ~/anaconda3/lib/python3.6/site-packages/shapely/geometry/polygon.py in geos_polygon_from_py(shell, holes)
#     481
#     482     if shell is not None:
# --> 483         ret = geos_linearring_from_py(shell)
#     484         if ret is None:
#     485             return None
#
# KeyboardInterrupt:
